# %% [markdown]
# ## Multimodal Research Synthetizer Demo
# - Stack: LangGraph v1+ with Local LLM
# - Supports: PDF/Text RAG, ArXiv search, Tavily web search
# - Includes persistent vector database with incremental updates
# - 100% local with Ollama
